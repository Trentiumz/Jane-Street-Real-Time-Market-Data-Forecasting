# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import polars as pl # data processing, CSV file I/O (e.g. pd.read_csv)
import pandas as pd
import os
from pathlib import Path
import tensorflow as tf
from tensorflow import keras
import time
from tensorflow.keras import layers
import re

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

import kaggle_evaluation.jane_street_inference_server

# %% [markdown]
# ## Define Inference Function

# %%
data_base_path = Path("/kaggle/input/js-feature-exploration/")
feature_data_path = data_base_path / Path("feature_data.csv")

feature_data_df = pl.read_csv(feature_data_path)
means = np.asarray(feature_data_df['mean']).astype('float32')
stds = np.asarray(feature_data_df['std']).astype('float32')

def r2_loss(y_true, y_pred):
    return tf.math.reduce_sum((y_true - y_pred) ** 2) / tf.math.reduce_sum((y_true - tf.reduce_mean(y_true)) ** 2)

feature_format = 'feature_\d\d'
responder_format = 'responder_\d'
lag_format = 'responder_\d_lag'
def chunk_features(chunk):
    return chunk[[i for i in chunk.columns if re.fullmatch(feature_format, i)]]
def chunk_lags(chunk):
    return chunk[[i for i in chunk.columns if re.fullmatch(lag_format, i)]]

def clean_features(features):
    return tf.where(
        tf.logical_or(tf.math.is_nan(features), tf.math.is_inf(features)), 
        means, 
        features)
def normalize_features(features):
    return (features - means) / tf.math.maximum(1.0, stds)
def clean_lags(lags):
    return tf.where(
        tf.logical_or(tf.math.is_nan(lags), tf.math.is_inf(lags)), 
        0.0, 
        lags)

def format_data(features, lags):
    return {
        'feature': normalize_features(clean_features(features)),
        'lags': clean_lags(lags)
    }

# %%
old_model = keras.models.load_model('/kaggle/input/js-prediction-training-1-model/fitted.keras', custom_objects={
    'r2_loss': r2_loss
})
new_model = keras.models.load_model('/kaggle/input/js-prediction-training-1-model/fitted.keras', custom_objects={
    'r2_loss': r2_loss
})

# %%
original_format = "(date_id)|(time_id)|(symbol_id)|(weight)|(feature_\d\d)|(responder_\d)"

# %%
feature_names = ['feature_00',
 'feature_01',
 'feature_02',
 'feature_03',
 'feature_04',
 'feature_05',
 'feature_06',
 'feature_07',
 'feature_08',
 'feature_09',
 'feature_10',
 'feature_11',
 'feature_12',
 'feature_13',
 'feature_14',
 'feature_15',
 'feature_16',
 'feature_17',
 'feature_18',
 'feature_19',
 'feature_20',
 'feature_21',
 'feature_22',
 'feature_23',
 'feature_24',
 'feature_25',
 'feature_26',
 'feature_27',
 'feature_28',
 'feature_29',
 'feature_30',
 'feature_31',
 'feature_32',
 'feature_33',
 'feature_34',
 'feature_35',
 'feature_36',
 'feature_37',
 'feature_38',
 'feature_39',
 'feature_40',
 'feature_41',
 'feature_42',
 'feature_43',
 'feature_44',
 'feature_45',
 'feature_46',
 'feature_47',
 'feature_48',
 'feature_49',
 'feature_50',
 'feature_51',
 'feature_52',
 'feature_53',
 'feature_54',
 'feature_55',
 'feature_56',
 'feature_57',
 'feature_58',
 'feature_59',
 'feature_60',
 'feature_61',
 'feature_62',
 'feature_63',
 'feature_64',
 'feature_65',
 'feature_66',
 'feature_67',
 'feature_68',
 'feature_69',
 'feature_70',
 'feature_71',
 'feature_72',
 'feature_73',
 'feature_74',
 'feature_75',
 'feature_76',
 'feature_77',
 'feature_78',
 'responder_0_lag',
 'responder_1_lag',
 'responder_2_lag',
 'responder_3_lag',
 'responder_4_lag',
 'responder_5_lag',
 'responder_6_lag',
 'responder_7_lag',
 'responder_8_lag']
responder_names = ['responder_0',
 'responder_1',
 'responder_2',
 'responder_3',
 'responder_4',
 'responder_5',
 'responder_6',
 'responder_7',
 'responder_8']

# %%
target = "responder_6"

# %%
def train_online_model(past_df, num_epochs = 15, elems_take = 100000, batch_size = 16384):
    print("training new model")
    model = keras.models.load_model('/kaggle/input/js-prediction-training-1-model/fitted.keras', custom_objects={
        'r2_loss': r2_loss
    })
    model.optimizer.learning_rate.assign(1e-4)

    if past_df is None or past_df.shape[0] == 0:
        return model

    past_df = past_df.sample(min(past_df.shape[0], elems_take))

    x_train = format_data(chunk_features(past_df), chunk_lags(past_df))
    y_train = past_df[target]
    batch_size = min(batch_size, past_df.shape[0])
    model.fit(x=x_train, y=y_train, batch_size=batch_size, epochs=num_epochs)

    return model

# %%
past_data_cols = feature_names + ['date_id', 'time_id', 'symbol_id']
past_responder_cols = responder_names + ['date_id', 'time_id', 'symbol_id']
past_df_cols = feature_names + responder_names + ['date_id', 'time_id', 'symbol_id']

class PastStorage:
    def __init__(self, max_time_series = 1000, max_days = 3):
        self.past_dfs = []
        self.past_features = []
        self.max_times = max_time_series
        self.max_days = max_days
    def reformat_lags(lags: pl.DataFrame | None):
        if lags is None:
            return None

        last_day_ans = lags
        for i in range(9):
            for j in [col for col in last_day_ans.columns if re.search(f'responder_{i}', col)]:
                last_day_ans = last_day_ans.rename({j: f"responder_{i}"})
        return last_day_ans
        
    def data_inc(self, test_full: pl.DataFrame, lags: pl.DataFrame | None):
        global past_data_cols, past_responder_cols
        
        # use the data from the previous day for today's information
        if lags is not None:
            if len(self.past_features) > 0:
                assert self.past_features[-1]['date_id'][0] == lags['date_id'][0] - 1

                lags = lags.with_columns(lags['date_id'] - 1)
                last_day_ans = PastStorage.reformat_lags(lags)
                to_append = pl.concat(self.past_features).join(last_day_ans, ['date_id', 'time_id', 'symbol_id'], how='left')
                for i in range(9):
                    to_append = to_append.filter(to_append[f'responder_{i}'].is_not_nan() & to_append[f'responder_{i}'].is_not_null())
    
                self.past_dfs.append(to_append[past_df_cols])
                print("Check for past dataframe cleanness:", to_append.shape, to_append['responder_0'].is_null().sum())
    
                self.past_features = []

        # append the data to the previous day... should always be the same as last_day_id
        if test_full is not None:
            self.past_features.append(test_full[past_data_cols])

        if len(self.past_dfs) > self.max_days:
            self.past_dfs = self.past_dfs[-self.max_days:]
        if len(self.past_features) > self.max_times:
            self.past_features = self.past_features[-self.max_times:]

# %%
lags_ : pl.DataFrame | None = None
storage = PastStorage()
days_per_update = 1
cur_day = 0

def reset_vars():
    global lags_, storage, cur_day
    lags_ = None
    storage = PastStorage()
    cur_day = 0
    new_model = keras.models.load_model('/kaggle/input/js-prediction-training-1-model/fitted.keras', custom_objects={
        'r2_loss': r2_loss
    })

# Replace this function with your inference code.
# You can return either a Pandas or Polars dataframe, though Polars is recommended.
# Each batch of predictions (except the very first) must be returned within 1 minute of the batch features being provided.
def predict(test: pl.DataFrame, lags: pl.DataFrame | None) -> pl.DataFrame | pd.DataFrame:
    global lags_, storage, old_model, new_model, cur_day, days_per_update
    
    if lags is not None:
        lags_ = lags
        
    if lags_ is not None:
        last_reading = lags_.group_by(('date_id', 'symbol_id'), maintain_order=True).last()
        for i in range(9):
            for j in [col for col in last_reading.columns if re.search(f'responder_{i}', col)]:
                last_reading = last_reading.rename({j: f"responder_{i}_lag"})

        selected_cols = ['date_id', 'symbol_id'] + [i for i in last_reading.columns if re.fullmatch(lag_format, i)]
        join_to = last_reading.with_columns(last_reading['date_id'])[selected_cols]
        test_grouped = test.join(join_to, ['date_id', 'symbol_id'], how='left')
    else:
        test_grouped = test
        for i in range(9):
            test_grouped = test_grouped.with_columns(pl.lit(None).cast(pl.Float32).alias(f"responder_{i}_lag"))
    
    input_features = format_data(chunk_features(test_grouped), chunk_lags(test_grouped))
    old_y = np.asarray(old_model.predict(input_features, verbose=0)).reshape((-1,))
    new_y = np.asarray(new_model.predict(input_features, verbose=0)).reshape((-1,))
    output_y = (old_y + new_y) / 2
    predictions = pl.DataFrame({
        "row_id": test['row_id'],
        "responder_6": output_y
    })

    storage.data_inc(test_grouped, lags)
    if lags is not None:
        cur_day += 1
        if cur_day == days_per_update:
            if len(storage.past_dfs) > 0:
                new_model = train_online_model(pl.concat(storage.past_dfs))
        cur_day %= days_per_update

    if isinstance(predictions, pl.DataFrame):
        assert predictions.columns == ['row_id', 'responder_6']
    elif isinstance(predictions, pd.DataFrame):
        assert (predictions.columns == ['row_id', 'responder_6']).all()
    else:
        raise TypeError('The predict function must return a DataFrame')
    # Confirm has as many rows as the test data.
    assert len(predictions) == len(test)

    return predictions

# %% [markdown]
# ## Test Inference

# %%
base_path = Path("/kaggle/input/jane-street-real-time-market-data-forecasting/")
train_path = base_path / Path("train.parquet/")

test_read_paths = [train_path / Path(f"partition_id={i}/part-0.parquet") for i in [9]]
original_format = "(date_id)|(time_id)|(symbol_id)|(weight)|(feature_\d\d)|(responder_\d)"
test_df = pl.concat([pl.read_parquet(i) for i in test_read_paths])
test_df = test_df

# %%
num_samples = 1000000

by_days = test_df[:num_samples].group_by(['date_id', 'time_id'], maintain_order=True)

# %%
last_date = None
last_lag = None

predictions = pl.DataFrame(schema={'responder_6': pl.Float32})
answers = pl.DataFrame(schema={'responder_6': pl.Float32})

# %%
lag_send_format = "(date_id)|(time_id)|(symbol_id)|(responder_\d)"
cur_ind = 0
max_time = 0
reset_vars()

for (date_id, time_id), df in by_days:
    cur_ind += 1
    if cur_ind % 100 == 0:
        print(f"Processing {cur_ind} with time {max_time}")
        max_time = 0
    lag_send = None
    if date_id != last_date:
        lag_send = last_lag
        if lag_send is not None:
            lag_send = lag_send.with_columns(lag_send['date_id'] + 1)
    else:
        lag_send = None

    df = df.with_columns(pl.Series(list(range(df.shape[0]))).alias("row_id"))

    start_time = time.time()
    result = predict(df, lag_send)
    end_time = time.time()
    max_time = max(max_time, end_time - start_time)
    
    predictions = pl.concat([predictions, result[['responder_6']]])
    answers = pl.concat([answers, df[['responder_6']]])
    
    responders = df[[i for i in df.columns if re.fullmatch(lag_send_format, i)]]

    if date_id != last_date:
        last_date = date_id
        last_lag = responders
    else:
        if last_lag is None:
            last_lag = responders
        else:
            last_lag = pl.concat([last_lag, responders])
# Out:
# Processing 100 with time 1.5594182014465332
# Processing 200 with time 0.2159113883972168
# Processing 300 with time 0.44808197021484375
# Processing 400 with time 0.20526480674743652
# Processing 500 with time 0.20457935333251953
# Processing 600 with time 0.21534419059753418
# Processing 700 with time 0.21021437644958496
# Processing 800 with time 0.2103424072265625
# Processing 900 with time 0.1977674961090088
# Check for past dataframe cleanness: (35816, 100) 0
# training new model
# Epoch 1/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 788ms/step - loss: 0.3935 - mean_absolute_error: 0.4249 - r2_score: 0.0069
# Epoch 2/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.3921 - mean_absolute_error: 0.4245 - r2_score: 0.0102
# Epoch 3/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.3949 - mean_absolute_error: 0.4256 - r2_score: 0.0068
# Epoch 4/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.3935 - mean_absolute_error: 0.4250 - r2_score: 0.0072
# Epoch 5/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.3962 - mean_absolute_error: 0.4255 - r2_score: 0.0107
# Epoch 6/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.3908 - mean_absolute_error: 0.4238 - r2_score: 0.0102
# Epoch 7/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.3977 - mean_absolute_error: 0.4254 - r2_score: 0.0104
# Epoch 8/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.3953 - mean_absolute_error: 0.4244 - r2_score: 0.0125
# Epoch 9/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.3946 - mean_absolute_error: 0.4243 - r2_score: 0.0126
# Epoch 10/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.3920 - mean_absolute_error: 0.4234 - r2_score: 0.0151
# Epoch 11/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.3908 - mean_absolute_error: 0.4221 - r2_score: 0.0145
# Epoch 12/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.3915 - mean_absolute_error: 0.4225 - r2_score: 0.0155
# Epoch 13/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.3904 - mean_absolute_error: 0.4216 - r2_score: 0.0176
# Epoch 14/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.3914 - mean_absolute_error: 0.4226 - r2_score: 0.0178
# Epoch 15/15
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.3903 - mean_absolute_error: 0.4219 - r2_score: 0.0179
# Processing 1000 with time 10.802116394042969
# Processing 1100 with time 0.22408318519592285
# Processing 1200 with time 0.22472357749938965
# Processing 1300 with time 0.22221016883850098
# Processing 1400 with time 0.23604702949523926
# Processing 1500 with time 0.22069478034973145
# Processing 1600 with time 0.2186603546142578
# Processing 1700 with time 0.21174836158752441
# Processing 1800 with time 0.21250224113464355
# Processing 1900 with time 0.5385537147521973
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 493ms/step - loss: 0.4168 - mean_absolute_error: 0.4322 - r2_score: 0.0143
# Epoch 2/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4144 - mean_absolute_error: 0.4300 - r2_score: 0.0114
# Epoch 3/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.4125 - mean_absolute_error: 0.4299 - r2_score: 0.0152
# Epoch 4/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4163 - mean_absolute_error: 0.4310 - r2_score: 0.0159
# Epoch 5/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.4159 - mean_absolute_error: 0.4306 - r2_score: 0.0133
# Epoch 6/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.4095 - mean_absolute_error: 0.4283 - r2_score: 0.0160
# Epoch 7/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - loss: 0.4139 - mean_absolute_error: 0.4295 - r2_score: 0.0163
# Epoch 8/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - loss: 0.4126 - mean_absolute_error: 0.4294 - r2_score: 0.0159
# Epoch 9/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - loss: 0.4097 - mean_absolute_error: 0.4292 - r2_score: 0.0156
# Epoch 10/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4108 - mean_absolute_error: 0.4295 - r2_score: 0.0170
# Epoch 11/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4110 - mean_absolute_error: 0.4291 - r2_score: 0.0180
# Epoch 12/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.4155 - mean_absolute_error: 0.4306 - r2_score: 0.0190
# Epoch 13/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4109 - mean_absolute_error: 0.4291 - r2_score: 0.0208
# Epoch 14/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.4149 - mean_absolute_error: 0.4304 - r2_score: 0.0213
# Epoch 15/15
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.4120 - mean_absolute_error: 0.4303 - r2_score: 0.0217
# Processing 2000 with time 15.111140251159668
# Processing 2100 with time 0.22568988800048828
# Processing 2200 with time 0.2151505947113037
# Processing 2300 with time 0.21713805198669434
# Processing 2400 with time 0.2240288257598877
# Processing 2500 with time 0.23032379150390625
# Processing 2600 with time 0.5330371856689453
# Processing 2700 with time 0.2193753719329834
# Processing 2800 with time 0.22924399375915527
# Processing 2900 with time 0.22451448440551758
# Check for past dataframe cleanness: (35816, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 352ms/step - loss: 0.4783 - mean_absolute_error: 0.4366 - r2_score: 0.0080
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4769 - mean_absolute_error: 0.4363 - r2_score: 0.0092
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.4759 - mean_absolute_error: 0.4349 - r2_score: 0.0085
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4743 - mean_absolute_error: 0.4353 - r2_score: 0.0088
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4774 - mean_absolute_error: 0.4359 - r2_score: 0.0102
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4747 - mean_absolute_error: 0.4350 - r2_score: 0.0100
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4793 - mean_absolute_error: 0.4362 - r2_score: 0.0105
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4749 - mean_absolute_error: 0.4352 - r2_score: 0.0113
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4721 - mean_absolute_error: 0.4344 - r2_score: 0.0119
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.4760 - mean_absolute_error: 0.4357 - r2_score: 0.0113
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4814 - mean_absolute_error: 0.4369 - r2_score: 0.0122
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4760 - mean_absolute_error: 0.4357 - r2_score: 0.0125
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4773 - mean_absolute_error: 0.4358 - r2_score: 0.0133
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4793 - mean_absolute_error: 0.4367 - r2_score: 0.0140
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4755 - mean_absolute_error: 0.4348 - r2_score: 0.0148
# Processing 3000 with time 17.775086402893066
# Processing 3100 with time 0.20614337921142578
# Processing 3200 with time 0.21778011322021484
# Processing 3300 with time 0.6085569858551025
# Processing 3400 with time 0.22070717811584473
# Processing 3500 with time 0.23864459991455078
# Processing 3600 with time 0.21130847930908203
# Processing 3700 with time 0.23764705657958984
# Processing 3800 with time 0.2284870147705078
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 338ms/step - loss: 0.4689 - mean_absolute_error: 0.4298 - r2_score: 0.0078
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4621 - mean_absolute_error: 0.4284 - r2_score: 0.0089
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.4660 - mean_absolute_error: 0.4283 - r2_score: 0.0097
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - loss: 0.4632 - mean_absolute_error: 0.4275 - r2_score: 0.0102
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - loss: 0.4694 - mean_absolute_error: 0.4299 - r2_score: 0.0090
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4667 - mean_absolute_error: 0.4281 - r2_score: 0.0107
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.4624 - mean_absolute_error: 0.4272 - r2_score: 0.0120
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.4643 - mean_absolute_error: 0.4279 - r2_score: 0.0115
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.4627 - mean_absolute_error: 0.4274 - r2_score: 0.0119
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.4716 - mean_absolute_error: 0.4304 - r2_score: 0.0125
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4672 - mean_absolute_error: 0.4288 - r2_score: 0.0110
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4605 - mean_absolute_error: 0.4270 - r2_score: 0.0153
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4588 - mean_absolute_error: 0.4268 - r2_score: 0.0142
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4602 - mean_absolute_error: 0.4267 - r2_score: 0.0145
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4649 - mean_absolute_error: 0.4275 - r2_score: 0.0175
# Processing 3900 with time 18.927816152572632
# Processing 4000 with time 0.24694299697875977
# Processing 4100 with time 0.5756778717041016
# Processing 4200 with time 0.2524833679199219
# Processing 4300 with time 0.2347409725189209
# Processing 4400 with time 0.2177753448486328
# Processing 4500 with time 0.2262730598449707
# Processing 4600 with time 0.2187643051147461
# Processing 4700 with time 0.24128961563110352
# Processing 4800 with time 0.22775936126708984
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 354ms/step - loss: 0.4690 - mean_absolute_error: 0.4282 - r2_score: 0.0057
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4686 - mean_absolute_error: 0.4287 - r2_score: 0.0058
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4675 - mean_absolute_error: 0.4283 - r2_score: 0.0072
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4687 - mean_absolute_error: 0.4282 - r2_score: 0.0074
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4652 - mean_absolute_error: 0.4276 - r2_score: 0.0091
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4649 - mean_absolute_error: 0.4272 - r2_score: 0.0090
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4720 - mean_absolute_error: 0.4287 - r2_score: 0.0082
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4682 - mean_absolute_error: 0.4289 - r2_score: 0.0109
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.4679 - mean_absolute_error: 0.4286 - r2_score: 0.0123
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.4679 - mean_absolute_error: 0.4278 - r2_score: 0.0112
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4660 - mean_absolute_error: 0.4268 - r2_score: 0.0106
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - loss: 0.4640 - mean_absolute_error: 0.4269 - r2_score: 0.0129
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - loss: 0.4668 - mean_absolute_error: 0.4274 - r2_score: 0.0119
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.4686 - mean_absolute_error: 0.4280 - r2_score: 0.0125
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4606 - mean_absolute_error: 0.4255 - r2_score: 0.0151
# Processing 4900 with time 19.49256420135498
# Processing 5000 with time 0.21983075141906738
# Processing 5100 with time 0.2223067283630371
# Processing 5200 with time 0.22345328330993652
# Processing 5300 with time 0.22420430183410645
# Processing 5400 with time 0.22891473770141602
# Processing 5500 with time 0.21550226211547852
# Processing 5600 with time 0.21953678131103516
# Processing 5700 with time 0.21529746055603027
# Processing 5800 with time 0.8070821762084961
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 341ms/step - loss: 0.4755 - mean_absolute_error: 0.4578 - r2_score: 0.0039
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4716 - mean_absolute_error: 0.4571 - r2_score: 0.0047
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4691 - mean_absolute_error: 0.4565 - r2_score: 0.0057
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4743 - mean_absolute_error: 0.4580 - r2_score: 0.0064
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.4727 - mean_absolute_error: 0.4575 - r2_score: 0.0083
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4718 - mean_absolute_error: 0.4568 - r2_score: 0.0072
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4729 - mean_absolute_error: 0.4580 - r2_score: 0.0091
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4684 - mean_absolute_error: 0.4572 - r2_score: 0.0102
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4698 - mean_absolute_error: 0.4568 - r2_score: 0.0099
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.4664 - mean_absolute_error: 0.4558 - r2_score: 0.0099
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.4659 - mean_absolute_error: 0.4553 - r2_score: 0.0112
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4672 - mean_absolute_error: 0.4557 - r2_score: 0.0112
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.4637 - mean_absolute_error: 0.4532 - r2_score: 0.0111
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4643 - mean_absolute_error: 0.4541 - r2_score: 0.0125
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4701 - mean_absolute_error: 0.4565 - r2_score: 0.0133
# Processing 5900 with time 18.18211269378662
# Processing 6000 with time 0.20345497131347656
# Processing 6100 with time 0.20412850379943848
# Processing 6200 with time 0.21906208992004395
# Processing 6300 with time 0.21356940269470215
# Processing 6400 with time 0.20543885231018066
# Processing 6500 with time 0.20245790481567383
# Processing 6600 with time 0.6338319778442383
# Processing 6700 with time 0.2522866725921631
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 373ms/step - loss: 0.4811 - mean_absolute_error: 0.4718 - r2_score: 0.0024
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4836 - mean_absolute_error: 0.4724 - r2_score: 0.0030
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4854 - mean_absolute_error: 0.4729 - r2_score: 0.0030
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4805 - mean_absolute_error: 0.4717 - r2_score: 0.0041
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4774 - mean_absolute_error: 0.4702 - r2_score: 0.0052
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.4786 - mean_absolute_error: 0.4706 - r2_score: 0.0047
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.4801 - mean_absolute_error: 0.4708 - r2_score: 0.0073
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4833 - mean_absolute_error: 0.4722 - r2_score: 0.0057
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4775 - mean_absolute_error: 0.4693 - r2_score: 0.0067
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4788 - mean_absolute_error: 0.4701 - r2_score: 0.0079
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.4803 - mean_absolute_error: 0.4713 - r2_score: 0.0070
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4813 - mean_absolute_error: 0.4716 - r2_score: 0.0094
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4830 - mean_absolute_error: 0.4714 - r2_score: 0.0092
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4811 - mean_absolute_error: 0.4708 - r2_score: 0.0093
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4784 - mean_absolute_error: 0.4706 - r2_score: 0.0088
# Processing 6800 with time 18.886627197265625
# Processing 6900 with time 0.20790982246398926
# Processing 7000 with time 0.2222440242767334
# Processing 7100 with time 0.2331850528717041
# Processing 7200 with time 0.22045493125915527
# Processing 7300 with time 0.20894622802734375
# Processing 7400 with time 0.8370342254638672
# Processing 7500 with time 0.27437448501586914
# Processing 7600 with time 0.23171544075012207
# Processing 7700 with time 0.2534632682800293
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 347ms/step - loss: 0.5588 - mean_absolute_error: 0.5041 - r2_score: 0.0084
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.5581 - mean_absolute_error: 0.5029 - r2_score: 0.0080
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.5588 - mean_absolute_error: 0.5036 - r2_score: 0.0110
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.5607 - mean_absolute_error: 0.5037 - r2_score: 0.0117
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 0.5566 - mean_absolute_error: 0.5021 - r2_score: 0.0129
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - loss: 0.5557 - mean_absolute_error: 0.5027 - r2_score: 0.0163
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.5600 - mean_absolute_error: 0.5034 - r2_score: 0.0168
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.5470 - mean_absolute_error: 0.5002 - r2_score: 0.0168
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.5568 - mean_absolute_error: 0.5028 - r2_score: 0.0166
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.5512 - mean_absolute_error: 0.5007 - r2_score: 0.0180
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.5572 - mean_absolute_error: 0.5027 - r2_score: 0.0198
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.5565 - mean_absolute_error: 0.5021 - r2_score: 0.0186
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.5548 - mean_absolute_error: 0.5017 - r2_score: 0.0202
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.5535 - mean_absolute_error: 0.5016 - r2_score: 0.0244
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.5493 - mean_absolute_error: 0.5002 - r2_score: 0.0222
# Processing 7800 with time 18.025768041610718
# Processing 7900 with time 0.22952485084533691
# Processing 8000 with time 0.2239704132080078
# Processing 8100 with time 0.2600724697113037
# Processing 8200 with time 0.2298579216003418
# Processing 8300 with time 0.6705055236816406
# Processing 8400 with time 0.2628190517425537
# Processing 8500 with time 0.24938225746154785
# Processing 8600 with time 0.23854780197143555
# Processing 8700 with time 0.21979618072509766
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 340ms/step - loss: 0.6035 - mean_absolute_error: 0.5267 - r2_score: 0.0026
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.5988 - mean_absolute_error: 0.5265 - r2_score: 0.0082
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.5973 - mean_absolute_error: 0.5262 - r2_score: 0.0112
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.6015 - mean_absolute_error: 0.5267 - r2_score: 0.0135
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.6026 - mean_absolute_error: 0.5259 - r2_score: 0.0186
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - loss: 0.5950 - mean_absolute_error: 0.5246 - r2_score: 0.0186
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - loss: 0.5972 - mean_absolute_error: 0.5247 - r2_score: 0.0229
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.5918 - mean_absolute_error: 0.5228 - r2_score: 0.0233
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.5944 - mean_absolute_error: 0.5240 - r2_score: 0.0249
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.5963 - mean_absolute_error: 0.5246 - r2_score: 0.0256
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.5938 - mean_absolute_error: 0.5243 - r2_score: 0.0260
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.5934 - mean_absolute_error: 0.5222 - r2_score: 0.0243
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.5919 - mean_absolute_error: 0.5230 - r2_score: 0.0278
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.5866 - mean_absolute_error: 0.5202 - r2_score: 0.0287
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.5947 - mean_absolute_error: 0.5234 - r2_score: 0.0266
# Processing 8800 with time 18.74269151687622
# Processing 8900 with time 0.21614646911621094
# Processing 9000 with time 0.21523451805114746
# Processing 9100 with time 0.21791768074035645
# Processing 9200 with time 0.622917890548706
# Processing 9300 with time 0.21418237686157227
# Processing 9400 with time 0.2267615795135498
# Processing 9500 with time 0.23965883255004883
# Processing 9600 with time 0.2552816867828369
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 381ms/step - loss: 0.6841 - mean_absolute_error: 0.5601 - r2_score: 0.0104
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.6832 - mean_absolute_error: 0.5596 - r2_score: 0.0118
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.6857 - mean_absolute_error: 0.5603 - r2_score: 0.0154
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.6779 - mean_absolute_error: 0.5584 - r2_score: 0.0165
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.6811 - mean_absolute_error: 0.5597 - r2_score: 0.0176
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 0.6693 - mean_absolute_error: 0.5550 - r2_score: 0.0204
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 0.6774 - mean_absolute_error: 0.5576 - r2_score: 0.0215
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.6737 - mean_absolute_error: 0.5558 - r2_score: 0.0212
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.6742 - mean_absolute_error: 0.5564 - r2_score: 0.0246
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.6738 - mean_absolute_error: 0.5560 - r2_score: 0.0231
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.6735 - mean_absolute_error: 0.5563 - r2_score: 0.0244
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.6727 - mean_absolute_error: 0.5565 - r2_score: 0.0254
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.6699 - mean_absolute_error: 0.5560 - r2_score: 0.0240
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.6739 - mean_absolute_error: 0.5562 - r2_score: 0.0272
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.6739 - mean_absolute_error: 0.5571 - r2_score: 0.0241
# Processing 9700 with time 18.97975754737854
# Processing 9800 with time 0.25052785873413086
# Processing 9900 with time 0.2424163818359375
# Processing 10000 with time 0.23380589485168457
# Processing 10100 with time 0.7328696250915527
# Processing 10200 with time 0.23345160484313965
# Processing 10300 with time 0.24704647064208984
# Processing 10400 with time 0.22724246978759766
# Processing 10500 with time 0.2343900203704834
# Processing 10600 with time 0.2516138553619385
# Check for past dataframe cleanness: (35816, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 365ms/step - loss: 0.7470 - mean_absolute_error: 0.5934 - r2_score: 0.0118
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.7371 - mean_absolute_error: 0.5899 - r2_score: 0.0146
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.7449 - mean_absolute_error: 0.5919 - r2_score: 0.0145
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.7426 - mean_absolute_error: 0.5909 - r2_score: 0.0166
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.7353 - mean_absolute_error: 0.5889 - r2_score: 0.0196
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.7395 - mean_absolute_error: 0.5894 - r2_score: 0.0170
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.7382 - mean_absolute_error: 0.5906 - r2_score: 0.0192
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.7361 - mean_absolute_error: 0.5904 - r2_score: 0.0215
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.7371 - mean_absolute_error: 0.5904 - r2_score: 0.0218
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.7306 - mean_absolute_error: 0.5865 - r2_score: 0.0199
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.7373 - mean_absolute_error: 0.5892 - r2_score: 0.0214
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.7381 - mean_absolute_error: 0.5901 - r2_score: 0.0232
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.7318 - mean_absolute_error: 0.5879 - r2_score: 0.0222
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.7375 - mean_absolute_error: 0.5884 - r2_score: 0.0256
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.7350 - mean_absolute_error: 0.5892 - r2_score: 0.0244
# Processing 10700 with time 19.018815755844116
# Processing 10800 with time 0.31069231033325195
# Processing 10900 with time 0.23603224754333496
# Processing 11000 with time 0.7008631229400635
# Processing 11100 with time 0.264523983001709
# Processing 11200 with time 0.24561643600463867
# Processing 11300 with time 0.24332189559936523
# Processing 11400 with time 0.24694108963012695
# Processing 11500 with time 0.28574657440185547
# Processing 11600 with time 0.23835492134094238
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 346ms/step - loss: 0.8924 - mean_absolute_error: 0.6404 - r2_score: 0.0147
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.8893 - mean_absolute_error: 0.6411 - r2_score: 0.0157
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.8919 - mean_absolute_error: 0.6390 - r2_score: 0.0157
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.8917 - mean_absolute_error: 0.6403 - r2_score: 0.0162
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.8847 - mean_absolute_error: 0.6391 - r2_score: 0.0167
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.8962 - mean_absolute_error: 0.6418 - r2_score: 0.0179
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.8856 - mean_absolute_error: 0.6397 - r2_score: 0.0204
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.8884 - mean_absolute_error: 0.6411 - r2_score: 0.0196
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.8865 - mean_absolute_error: 0.6400 - r2_score: 0.0212
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.8900 - mean_absolute_error: 0.6399 - r2_score: 0.0199
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.8846 - mean_absolute_error: 0.6396 - r2_score: 0.0199
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.8840 - mean_absolute_error: 0.6380 - r2_score: 0.0217
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.8877 - mean_absolute_error: 0.6404 - r2_score: 0.0207
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.8889 - mean_absolute_error: 0.6414 - r2_score: 0.0204
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.8825 - mean_absolute_error: 0.6396 - r2_score: 0.0223
# Processing 11700 with time 19.014721155166626
# Processing 11800 with time 0.24393916130065918
# Processing 11900 with time 1.0108962059020996
# Processing 12000 with time 0.26158571243286133
# Processing 12100 with time 0.23769330978393555
# Processing 12200 with time 0.24077081680297852
# Processing 12300 with time 0.25662899017333984
# Processing 12400 with time 0.22314453125
# Processing 12500 with time 0.23096036911010742
# Check for past dataframe cleanness: (30008, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 363ms/step - loss: 0.9979 - mean_absolute_error: 0.6847 - r2_score: 0.0158
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 1.0032 - mean_absolute_error: 0.6858 - r2_score: 0.0171
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.9995 - mean_absolute_error: 0.6847 - r2_score: 0.0181
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 1.0011 - mean_absolute_error: 0.6856 - r2_score: 0.0185
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.9972 - mean_absolute_error: 0.6837 - r2_score: 0.0186
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 1.0006 - mean_absolute_error: 0.6851 - r2_score: 0.0214
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - loss: 1.0024 - mean_absolute_error: 0.6856 - r2_score: 0.0205
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 0.9909 - mean_absolute_error: 0.6824 - r2_score: 0.0197
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.9971 - mean_absolute_error: 0.6844 - r2_score: 0.0203
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 1.0043 - mean_absolute_error: 0.6857 - r2_score: 0.0228
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 1.0002 - mean_absolute_error: 0.6849 - r2_score: 0.0207
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.9920 - mean_absolute_error: 0.6834 - r2_score: 0.0237
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.9899 - mean_absolute_error: 0.6827 - r2_score: 0.0237
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.9920 - mean_absolute_error: 0.6828 - r2_score: 0.0250
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.9864 - mean_absolute_error: 0.6818 - r2_score: 0.0239
# Processing 12600 with time 20.3107488155365
# Processing 12700 with time 0.2368760108947754
# Processing 12800 with time 0.23993992805480957
# Processing 12900 with time 0.7945237159729004
# Processing 13000 with time 0.2502310276031494
# Processing 13100 with time 0.2502593994140625
# Processing 13200 with time 0.2421574592590332
# Processing 13300 with time 0.2387218475341797
# Processing 13400 with time 0.24544596672058105
# Processing 13500 with time 0.22680139541625977
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 346ms/step - loss: 0.9079 - mean_absolute_error: 0.6489 - r2_score: 0.0122
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.9014 - mean_absolute_error: 0.6477 - r2_score: 0.0132
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.9000 - mean_absolute_error: 0.6470 - r2_score: 0.0141
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.9018 - mean_absolute_error: 0.6471 - r2_score: 0.0147
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.9057 - mean_absolute_error: 0.6487 - r2_score: 0.0148
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.9008 - mean_absolute_error: 0.6464 - r2_score: 0.0175
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.8993 - mean_absolute_error: 0.6470 - r2_score: 0.0182
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.9019 - mean_absolute_error: 0.6479 - r2_score: 0.0180
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.8959 - mean_absolute_error: 0.6463 - r2_score: 0.0193
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.8936 - mean_absolute_error: 0.6460 - r2_score: 0.0189
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.8900 - mean_absolute_error: 0.6460 - r2_score: 0.0216
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.8901 - mean_absolute_error: 0.6452 - r2_score: 0.0224
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.8882 - mean_absolute_error: 0.6443 - r2_score: 0.0226
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.8917 - mean_absolute_error: 0.6458 - r2_score: 0.0227
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.8862 - mean_absolute_error: 0.6441 - r2_score: 0.0226
# Processing 13600 with time 18.48695945739746
# Processing 13700 with time 0.2431318759918213
# Processing 13800 with time 0.23563194274902344
# Processing 13900 with time 0.9630374908447266
# Processing 14000 with time 0.25456881523132324
# Processing 14100 with time 0.2509191036224365
# Processing 14200 with time 0.25013208389282227
# Processing 14300 with time 0.23297834396362305
# Processing 14400 with time 0.24177956581115723
# Processing 14500 with time 0.2863283157348633
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 364ms/step - loss: 0.6623 - mean_absolute_error: 0.5551 - r2_score: 0.0119
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - loss: 0.6634 - mean_absolute_error: 0.5555 - r2_score: 0.0126
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 0.6649 - mean_absolute_error: 0.5551 - r2_score: 0.0135
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.6647 - mean_absolute_error: 0.5550 - r2_score: 0.0156
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.6608 - mean_absolute_error: 0.5555 - r2_score: 0.0163
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.6596 - mean_absolute_error: 0.5542 - r2_score: 0.0164
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.6583 - mean_absolute_error: 0.5545 - r2_score: 0.0189
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.6574 - mean_absolute_error: 0.5546 - r2_score: 0.0204
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.6605 - mean_absolute_error: 0.5549 - r2_score: 0.0199
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.6566 - mean_absolute_error: 0.5534 - r2_score: 0.0221
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.6584 - mean_absolute_error: 0.5538 - r2_score: 0.0219
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.6584 - mean_absolute_error: 0.5543 - r2_score: 0.0241
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.6629 - mean_absolute_error: 0.5551 - r2_score: 0.0237
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.6592 - mean_absolute_error: 0.5534 - r2_score: 0.0243
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.6637 - mean_absolute_error: 0.5546 - r2_score: 0.0236
# Processing 14600 with time 19.020593404769897
# Processing 14700 with time 0.23424458503723145
# Processing 14800 with time 0.23757147789001465
# Processing 14900 with time 0.7700235843658447
# Processing 15000 with time 0.30690956115722656
# Processing 15100 with time 0.2640087604522705
# Processing 15200 with time 0.2675318717956543
# Processing 15300 with time 0.23243236541748047
# Processing 15400 with time 0.23392128944396973
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 355ms/step - loss: 0.5757 - mean_absolute_error: 0.5170 - r2_score: 0.0123
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.5727 - mean_absolute_error: 0.5153 - r2_score: 0.0133
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.5795 - mean_absolute_error: 0.5171 - r2_score: 0.0150
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.5783 - mean_absolute_error: 0.5172 - r2_score: 0.0145
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.5797 - mean_absolute_error: 0.5161 - r2_score: 0.0156
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.5688 - mean_absolute_error: 0.5141 - r2_score: 0.0177
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - loss: 0.5769 - mean_absolute_error: 0.5161 - r2_score: 0.0173
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - loss: 0.5730 - mean_absolute_error: 0.5154 - r2_score: 0.0178
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.5759 - mean_absolute_error: 0.5165 - r2_score: 0.0197
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.5753 - mean_absolute_error: 0.5157 - r2_score: 0.0199
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.5681 - mean_absolute_error: 0.5130 - r2_score: 0.0218
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.5716 - mean_absolute_error: 0.5145 - r2_score: 0.0208
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.5678 - mean_absolute_error: 0.5135 - r2_score: 0.0215
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.5703 - mean_absolute_error: 0.5143 - r2_score: 0.0214
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.5689 - mean_absolute_error: 0.5127 - r2_score: 0.0235
# Processing 15500 with time 19.40670371055603
# Processing 15600 with time 0.22821331024169922
# Processing 15700 with time 0.24174880981445312
# Processing 15800 with time 0.25807762145996094
# Processing 15900 with time 0.7210345268249512
# Processing 16000 with time 0.2669813632965088
# Processing 16100 with time 0.27011919021606445
# Processing 16200 with time 0.27913856506347656
# Processing 16300 with time 0.27345871925354004
# Processing 16400 with time 0.2582998275756836
# Check for past dataframe cleanness: (36784, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 358ms/step - loss: 0.5232 - mean_absolute_error: 0.4865 - r2_score: 0.0078
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.5246 - mean_absolute_error: 0.4865 - r2_score: 0.0092
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.5205 - mean_absolute_error: 0.4850 - r2_score: 0.0104
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.5245 - mean_absolute_error: 0.4866 - r2_score: 0.0117
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.5194 - mean_absolute_error: 0.4858 - r2_score: 0.0135
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.5194 - mean_absolute_error: 0.4846 - r2_score: 0.0119
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.5211 - mean_absolute_error: 0.4853 - r2_score: 0.0131
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.5133 - mean_absolute_error: 0.4825 - r2_score: 0.0155
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.5206 - mean_absolute_error: 0.4848 - r2_score: 0.0143
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.5269 - mean_absolute_error: 0.4855 - r2_score: 0.0160
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.5166 - mean_absolute_error: 0.4832 - r2_score: 0.0192
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.5168 - mean_absolute_error: 0.4840 - r2_score: 0.0175
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.5187 - mean_absolute_error: 0.4844 - r2_score: 0.0187
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 0.5187 - mean_absolute_error: 0.4840 - r2_score: 0.0200
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - loss: 0.5178 - mean_absolute_error: 0.4834 - r2_score: 0.0186
# Processing 16500 with time 19.07214117050171
# Processing 16600 with time 0.22622323036193848
# Processing 16700 with time 0.2407221794128418
# Processing 16800 with time 0.23360538482666016
# Processing 16900 with time 0.7277626991271973
# Processing 17000 with time 0.2554037570953369
# Processing 17100 with time 0.27928972244262695
# Processing 17200 with time 0.25760793685913086
# Processing 17300 with time 0.2872273921966553
# Processing 17400 with time 0.2713353633880615
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 364ms/step - loss: 0.4925 - mean_absolute_error: 0.4671 - r2_score: 0.0024
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.4921 - mean_absolute_error: 0.4671 - r2_score: 0.0052
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4867 - mean_absolute_error: 0.4650 - r2_score: 0.0076
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.4935 - mean_absolute_error: 0.4662 - r2_score: 0.0071
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.4884 - mean_absolute_error: 0.4633 - r2_score: 0.0060
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.4864 - mean_absolute_error: 0.4641 - r2_score: 0.0061
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.4941 - mean_absolute_error: 0.4664 - r2_score: 0.0068
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.4864 - mean_absolute_error: 0.4638 - r2_score: 0.0086
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4911 - mean_absolute_error: 0.4657 - r2_score: 0.0088
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4827 - mean_absolute_error: 0.4621 - r2_score: 0.0081
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.4879 - mean_absolute_error: 0.4647 - r2_score: 0.0083
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.4882 - mean_absolute_error: 0.4642 - r2_score: 0.0102
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.4831 - mean_absolute_error: 0.4622 - r2_score: 0.0086
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.4864 - mean_absolute_error: 0.4638 - r2_score: 0.0099
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4920 - mean_absolute_error: 0.4650 - r2_score: 0.0097
# Processing 17500 with time 18.35245943069458
# Processing 17600 with time 0.25354719161987305
# Processing 17700 with time 0.23141241073608398
# Processing 17800 with time 0.24405431747436523
# Processing 17900 with time 0.24109888076782227
# Processing 18000 with time 0.7746086120605469
# Processing 18100 with time 0.25041890144348145
# Processing 18200 with time 0.27776598930358887
# Processing 18300 with time 0.25283074378967285
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 394ms/step - loss: 0.4113 - mean_absolute_error: 0.4249 - r2_score: 0.0017
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.4183 - mean_absolute_error: 0.4264 - r2_score: 0.0017
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.4108 - mean_absolute_error: 0.4249 - r2_score: 0.0023
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4124 - mean_absolute_error: 0.4249 - r2_score: 0.0016
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.4117 - mean_absolute_error: 0.4243 - r2_score: 0.0033
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4085 - mean_absolute_error: 0.4237 - r2_score: 0.0049
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4134 - mean_absolute_error: 0.4241 - r2_score: 0.0028
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4143 - mean_absolute_error: 0.4247 - r2_score: 0.0046
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4129 - mean_absolute_error: 0.4240 - r2_score: 0.0055
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4133 - mean_absolute_error: 0.4244 - r2_score: 0.0064
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.4153 - mean_absolute_error: 0.4247 - r2_score: 0.0057
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.4099 - mean_absolute_error: 0.4239 - r2_score: 0.0065
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.4160 - mean_absolute_error: 0.4245 - r2_score: 0.0062
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.4109 - mean_absolute_error: 0.4236 - r2_score: 0.0083
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4132 - mean_absolute_error: 0.4244 - r2_score: 0.0088
# Processing 18400 with time 18.84212303161621
# Processing 18500 with time 0.2469329833984375
# Processing 18600 with time 0.268322229385376
# Processing 18700 with time 0.2426772117614746
# Processing 18800 with time 0.2806508541107178
# Processing 18900 with time 0.24146080017089844
# Processing 19000 with time 0.24540424346923828
# Processing 19100 with time 1.106743335723877
# Processing 19200 with time 0.2746272087097168
# Processing 19300 with time 0.26384568214416504
# Check for past dataframe cleanness: (36784, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 358ms/step - loss: 0.4787 - mean_absolute_error: 0.4586 - r2_score: -2.0809e-05
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4815 - mean_absolute_error: 0.4578 - r2_score: 0.0021
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.4740 - mean_absolute_error: 0.4563 - r2_score: 0.0026
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4758 - mean_absolute_error: 0.4564 - r2_score: 0.0031
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4781 - mean_absolute_error: 0.4569 - r2_score: 0.0027
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.4758 - mean_absolute_error: 0.4555 - r2_score: 0.0043
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4751 - mean_absolute_error: 0.4566 - r2_score: 0.0047
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.4693 - mean_absolute_error: 0.4546 - r2_score: 0.0044
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.4775 - mean_absolute_error: 0.4562 - r2_score: 0.0050
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.4795 - mean_absolute_error: 0.4566 - r2_score: 0.0065
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.4704 - mean_absolute_error: 0.4545 - r2_score: 0.0056
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4764 - mean_absolute_error: 0.4557 - r2_score: 0.0058
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.4795 - mean_absolute_error: 0.4566 - r2_score: 0.0055
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4746 - mean_absolute_error: 0.4556 - r2_score: 0.0059
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.4737 - mean_absolute_error: 0.4552 - r2_score: 0.0061
# Processing 19400 with time 18.886341333389282
# Processing 19500 with time 0.25382113456726074
# Processing 19600 with time 0.22990202903747559
# Processing 19700 with time 0.21538662910461426
# Processing 19800 with time 0.23833680152893066
# Processing 19900 with time 0.27135252952575684
# Processing 20000 with time 0.2707641124725342
# Processing 20100 with time 0.22633624076843262
# Processing 20200 with time 1.041795015335083
# Processing 20300 with time 0.2516632080078125
# Check for past dataframe cleanness: (35816, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 348ms/step - loss: 0.5476 - mean_absolute_error: 0.4875 - r2_score: 0.0067
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.5463 - mean_absolute_error: 0.4882 - r2_score: 0.0074
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.5468 - mean_absolute_error: 0.4880 - r2_score: 0.0077
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - loss: 0.5498 - mean_absolute_error: 0.4893 - r2_score: 0.0073
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - loss: 0.5509 - mean_absolute_error: 0.4894 - r2_score: 0.0097
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.5458 - mean_absolute_error: 0.4869 - r2_score: 0.0091
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.5545 - mean_absolute_error: 0.4903 - r2_score: 0.0092
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.5480 - mean_absolute_error: 0.4890 - r2_score: 0.0102
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.5462 - mean_absolute_error: 0.4878 - r2_score: 0.0086
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.5497 - mean_absolute_error: 0.4898 - r2_score: 0.0124
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.5514 - mean_absolute_error: 0.4899 - r2_score: 0.0104
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.5455 - mean_absolute_error: 0.4877 - r2_score: 0.0114
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.5444 - mean_absolute_error: 0.4865 - r2_score: 0.0113
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.5414 - mean_absolute_error: 0.4862 - r2_score: 0.0148
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.5419 - mean_absolute_error: 0.4869 - r2_score: 0.0120
# Processing 20400 with time 18.703518390655518
# Processing 20500 with time 0.23093247413635254
# Processing 20600 with time 0.2309892177581787
# Processing 20700 with time 0.23026704788208008
# Processing 20800 with time 0.22213983535766602
# Processing 20900 with time 0.25206494331359863
# Processing 21000 with time 0.2278594970703125
# Processing 21100 with time 0.22503089904785156
# Processing 21200 with time 0.22515487670898438
# Check for past dataframe cleanness: (31944, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 391ms/step - loss: 0.6744 - mean_absolute_error: 0.5417 - r2_score: 0.0074
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - loss: 0.6808 - mean_absolute_error: 0.5431 - r2_score: 0.0115
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.6780 - mean_absolute_error: 0.5425 - r2_score: 0.0095
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.6901 - mean_absolute_error: 0.5453 - r2_score: 0.0094
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.6812 - mean_absolute_error: 0.5429 - r2_score: 0.0102
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.6804 - mean_absolute_error: 0.5436 - r2_score: 0.0116
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.6865 - mean_absolute_error: 0.5448 - r2_score: 0.0113
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.6777 - mean_absolute_error: 0.5426 - r2_score: 0.0133
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.6770 - mean_absolute_error: 0.5420 - r2_score: 0.0106
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.6827 - mean_absolute_error: 0.5435 - r2_score: 0.0134
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.6779 - mean_absolute_error: 0.5426 - r2_score: 0.0130
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.6798 - mean_absolute_error: 0.5414 - r2_score: 0.0137
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.6826 - mean_absolute_error: 0.5424 - r2_score: 0.0135
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.6774 - mean_absolute_error: 0.5406 - r2_score: 0.0152
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.6814 - mean_absolute_error: 0.5428 - r2_score: 0.0160
# Processing 21300 with time 19.98009443283081
# Processing 21400 with time 0.24631357192993164
# Processing 21500 with time 0.238844633102417
# Processing 21600 with time 0.22673439979553223
# Processing 21700 with time 0.22996020317077637
# Processing 21800 with time 0.24498844146728516
# Processing 21900 with time 0.24800324440002441
# Processing 22000 with time 0.23498225212097168
# Processing 22100 with time 0.2301316261291504
# Processing 22200 with time 0.23659229278564453
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 348ms/step - loss: 0.6738 - mean_absolute_error: 0.5388 - r2_score: 0.0237
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.6782 - mean_absolute_error: 0.5411 - r2_score: 0.0245
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.6721 - mean_absolute_error: 0.5388 - r2_score: 0.0254
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.6699 - mean_absolute_error: 0.5376 - r2_score: 0.0239
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.6665 - mean_absolute_error: 0.5361 - r2_score: 0.0269
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.6674 - mean_absolute_error: 0.5375 - r2_score: 0.0256
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.6745 - mean_absolute_error: 0.5392 - r2_score: 0.0293
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.6659 - mean_absolute_error: 0.5366 - r2_score: 0.0290
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.6605 - mean_absolute_error: 0.5342 - r2_score: 0.0260
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.6708 - mean_absolute_error: 0.5362 - r2_score: 0.0280
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.6676 - mean_absolute_error: 0.5374 - r2_score: 0.0269
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.6711 - mean_absolute_error: 0.5383 - r2_score: 0.0317
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.6706 - mean_absolute_error: 0.5372 - r2_score: 0.0307
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.6686 - mean_absolute_error: 0.5371 - r2_score: 0.0292
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.6714 - mean_absolute_error: 0.5380 - r2_score: 0.0322
# Processing 22300 with time 19.437288999557495
# Processing 22400 with time 0.24065279960632324
# Processing 22500 with time 0.24687838554382324
# Processing 22600 with time 0.2596700191497803
# Processing 22700 with time 0.21834468841552734
# Processing 22800 with time 0.24015283584594727
# Processing 22900 with time 0.22477269172668457
# Processing 23000 with time 0.21463513374328613
# Processing 23100 with time 0.21391940116882324
# Processing 23200 with time 0.22881197929382324
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 359ms/step - loss: 0.5704 - mean_absolute_error: 0.4893 - r2_score: 0.0247
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - loss: 0.5664 - mean_absolute_error: 0.4885 - r2_score: 0.0263
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.5697 - mean_absolute_error: 0.4901 - r2_score: 0.0256
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.5668 - mean_absolute_error: 0.4886 - r2_score: 0.0245
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.5698 - mean_absolute_error: 0.4887 - r2_score: 0.0283
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.5669 - mean_absolute_error: 0.4886 - r2_score: 0.0274
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.5712 - mean_absolute_error: 0.4898 - r2_score: 0.0316
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.5621 - mean_absolute_error: 0.4860 - r2_score: 0.0326
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.5656 - mean_absolute_error: 0.4881 - r2_score: 0.0296
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.5700 - mean_absolute_error: 0.4885 - r2_score: 0.0307
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.5623 - mean_absolute_error: 0.4865 - r2_score: 0.0309
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.5668 - mean_absolute_error: 0.4880 - r2_score: 0.0339
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.5613 - mean_absolute_error: 0.4863 - r2_score: 0.0315
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.5628 - mean_absolute_error: 0.4880 - r2_score: 0.0322
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.5575 - mean_absolute_error: 0.4853 - r2_score: 0.0333
# Processing 23300 with time 19.46766996383667
# Processing 23400 with time 0.19681191444396973
# Processing 23500 with time 0.9159517288208008
# Processing 23600 with time 0.22200942039489746
# Processing 23700 with time 0.23923254013061523
# Processing 23800 with time 0.20969891548156738
# Processing 23900 with time 0.23706603050231934
# Processing 24000 with time 0.2125234603881836
# Processing 24100 with time 0.22559881210327148
# Processing 24200 with time 0.21695327758789062
# Check for past dataframe cleanness: (36784, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 338ms/step - loss: 0.4599 - mean_absolute_error: 0.4475 - r2_score: 0.0245
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4558 - mean_absolute_error: 0.4465 - r2_score: 0.0254
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.4504 - mean_absolute_error: 0.4455 - r2_score: 0.0278
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.4508 - mean_absolute_error: 0.4454 - r2_score: 0.0311
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4521 - mean_absolute_error: 0.4467 - r2_score: 0.0276
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4518 - mean_absolute_error: 0.4458 - r2_score: 0.0317
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4565 - mean_absolute_error: 0.4482 - r2_score: 0.0322
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4532 - mean_absolute_error: 0.4475 - r2_score: 0.0318
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4529 - mean_absolute_error: 0.4470 - r2_score: 0.0331
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4480 - mean_absolute_error: 0.4449 - r2_score: 0.0325
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4509 - mean_absolute_error: 0.4465 - r2_score: 0.0374
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4491 - mean_absolute_error: 0.4453 - r2_score: 0.0365
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4506 - mean_absolute_error: 0.4455 - r2_score: 0.0369
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.4526 - mean_absolute_error: 0.4462 - r2_score: 0.0351
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4541 - mean_absolute_error: 0.4469 - r2_score: 0.0402
# Processing 24300 with time 17.537039518356323
# Processing 24400 with time 0.2145214080810547
# Processing 24500 with time 0.20700478553771973
# Processing 24600 with time 0.21932649612426758
# Processing 24700 with time 0.8011834621429443
# Processing 24800 with time 0.2255570888519287
# Processing 24900 with time 0.21311664581298828
# Processing 25000 with time 0.22356319427490234
# Processing 25100 with time 0.21956849098205566
# Check for past dataframe cleanness: (34848, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 369ms/step - loss: 0.4389 - mean_absolute_error: 0.4398 - r2_score: 0.0071
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.4450 - mean_absolute_error: 0.4417 - r2_score: 0.0095
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4432 - mean_absolute_error: 0.4413 - r2_score: 0.0088
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.4369 - mean_absolute_error: 0.4394 - r2_score: 0.0117
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4350 - mean_absolute_error: 0.4390 - r2_score: 0.0121
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.4423 - mean_absolute_error: 0.4409 - r2_score: 0.0115
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4348 - mean_absolute_error: 0.4391 - r2_score: 0.0140
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4369 - mean_absolute_error: 0.4397 - r2_score: 0.0148
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4369 - mean_absolute_error: 0.4402 - r2_score: 0.0151
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4386 - mean_absolute_error: 0.4409 - r2_score: 0.0168
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.4354 - mean_absolute_error: 0.4399 - r2_score: 0.0171
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.4397 - mean_absolute_error: 0.4414 - r2_score: 0.0173
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.4337 - mean_absolute_error: 0.4394 - r2_score: 0.0176
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.4355 - mean_absolute_error: 0.4397 - r2_score: 0.0175
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 0.4347 - mean_absolute_error: 0.4402 - r2_score: 0.0179
# Processing 25200 with time 18.87769842147827
# Processing 25300 with time 0.2109661102294922
# Processing 25400 with time 0.24846529960632324
# Processing 25500 with time 0.21039676666259766
# Processing 25600 with time 0.21276330947875977
# Processing 25700 with time 0.23384952545166016
# Processing 25800 with time 0.23952984809875488
# Processing 25900 with time 0.23804211616516113
# Processing 26000 with time 1.1811881065368652
# Processing 26100 with time 0.2518336772918701
# Check for past dataframe cleanness: (37752, 100) 0
# training new model
# Epoch 1/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 365ms/step - loss: 0.5376 - mean_absolute_error: 0.4851 - r2_score: 0.0108
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - loss: 0.5308 - mean_absolute_error: 0.4825 - r2_score: 0.0117
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.5334 - mean_absolute_error: 0.4837 - r2_score: 0.0124
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 0.5325 - mean_absolute_error: 0.4839 - r2_score: 0.0124
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.5360 - mean_absolute_error: 0.4853 - r2_score: 0.0143
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.5300 - mean_absolute_error: 0.4822 - r2_score: 0.0149
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.5276 - mean_absolute_error: 0.4823 - r2_score: 0.0151
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.5228 - mean_absolute_error: 0.4804 - r2_score: 0.0160
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.5346 - mean_absolute_error: 0.4844 - r2_score: 0.0175
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.5270 - mean_absolute_error: 0.4822 - r2_score: 0.0178
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.5306 - mean_absolute_error: 0.4833 - r2_score: 0.0189
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.5273 - mean_absolute_error: 0.4819 - r2_score: 0.0182
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.5331 - mean_absolute_error: 0.4846 - r2_score: 0.0195
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.5275 - mean_absolute_error: 0.4826 - r2_score: 0.0198
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.5306 - mean_absolute_error: 0.4838 - r2_score: 0.0195
# Processing 26200 with time 18.939876556396484
# Processing 26300 with time 0.22110843658447266
